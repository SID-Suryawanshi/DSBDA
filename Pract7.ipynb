# %%
import nltk
import re
import pandas as pd

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("averaged_perceptron_tagger")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Siddhant\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Siddhant\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Siddhant\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Siddhant\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Siddhant\AppData\Roaming\nltk_data...
# True

# %%
text = "Tokenization is the first step in text analytics."
print(text)
# Out:
# Tokenization is the first step in text analytics.

# %%
tokenized_text = sent_tokenize(text)

print(tokenized_text)
# Out:
# ['Tokenization is the first step in text analytics.']

# %%
tokenized_word = word_tokenize(text)

# %%
print(tokenized_word)
# Out:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.']

# %%
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {"won't", "don't", 'few', 'here', "they'd", 'as', 'me', 'you', 'yours', "aren't", 'up', 'all', 'been', 'during', 'shouldn', "didn't", 'i', 'most', 'had', 'some', 'further', 'your', "she'll", 'until', 'm', 'our', 'wouldn', 'each', 'for', 're', "we'll", 'themselves', 'by', 'haven', "he's", 'than', 'down', 'into', "shouldn't", 'should', 'after', 'once', 'then', 'does', 'who', 'again', "it'd", 'them', 'can', 'hasn', 'o', 'just', 'under', 'at', 'couldn', 'below', 'there', "hadn't", 'how', 'y', 'shan', 'am', 'a', 'him', 'weren', 'against', "shan't", 'or', "she'd", "they're", "we'd", 'isn', 'she', 'when', "isn't", "they'll", 't', 'were', 'with', 'very', 'out', 'through', 'ourselves', 'about', 'to', 'own', 'only', "hasn't", 'd', 'too', 'hers', "you'd", 'herself', 'off', "couldn't", 'did', 'mustn', 'be', 'because', "needn't", "they've", 'he', 'over', 'doing', 'in', 'those', "you'll", "we've", 'but', 'yourself', 'now', 'aren', 'being', 'yourselves', 'the', 'its', "i'd", 'myself', 'while', "i'll", 'whom', "wouldn't", 'wasn', 'if', 'have', "wasn't", 'from', "it'll", 'ours', 'between', 'where', 'hadn', 'theirs', 'are', "haven't", 'having', 'itself', 's', 'any', "mightn't", "you're", 'what', "you've", 'we', 'these', 'same', 'and', 'ma', 'it', "doesn't", 'ain', 'nor', 'why', 'which', 'their', 'an', 'was', 'that', 'both', 'so', 'mightn', 'no', 'not', 'above', 'they', 'of', 'didn', 've', 'doesn', 'is', "she's", "i've", 'on', 'her', 'other', 'll', 'won', 'has', "he'll", 'before', 'more', "mustn't", "we're", 'don', "i'm", 'do', "weren't", 'this', 'himself', 'such', "it's", "that'll", 'will', 'needn', 'his', "he'd", "should've", 'my'}

# %%
text = "How to remove stop words with NLTK library in Python?"

text = re.sub("[^a-zA-Z]", " ", text)
tokens = word_tokenize(text.lower())

filtered_text = []

for w in tokens :
    if w not in stop_words :
        filtered_text.append(w)

print("Tokenized Sentence : ", tokens)

print("Filtered Sentence : ", filtered_text)
# Out:
# Tokenized Sentence :  ['how', 'to', 'remove', 'stop', 'words', 'with', 'nltk', 'library', 'in', 'python']
# Filtered Sentence :  ['remove', 'stop', 'words', 'nltk', 'library', 'python']

# %%
e_words = ["wait", "waiting", "waited", "waits"]

ps = PorterStemmer()

for w in e_words:
    rootWord = ps.stem(w)
    print(rootWord)
# Out:
# wait
# wait
# wait
# wait

# %%
wordnet_lemmatizer = WordNetLemmatizer()

text = "studies studying cries cry"

tokenization = nltk.word_tokenize(text)

for w in tokenization:
    print("Lemma for {} is {} "  .format(w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry

# %%
data = "The pink sweater fit her perfectly"

words = word_tokenize(data)

for w in words:
    print(nltk.pos_tag([w]))
# Out:
# [('The', 'DT')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Siddhant\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
d0 = "Jupiter is the largest Gaseous Planet"

d1 = "Mars is the fourth planet from the sun"

string = [d0, d1]

tfIdf = TfidfVectorizer()

result = tfIdf.fit_transform(string)

print("Word indices : ", tfIdf.vocabulary_)

print("\nTF-IDF Values : \n")
print(result)
# Out:
# Word indices :  {'jupiter': 4, 'is': 3, 'the': 9, 'largest': 5, 'gaseous': 2, 'planet': 7, 'mars': 6, 'fourth': 0, 'from': 1, 'sun': 8}
#
# TF-IDF Values :
#
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 13 stored elements and shape (2, 10)>
#   Coords	Values
#   (0, 4)	0.4704264280854632
#   (0, 3)	0.3347122780719073
#   (0, 9)	0.3347122780719073
#   (0, 5)	0.4704264280854632
#   (0, 2)	0.4704264280854632
#   (0, 7)	0.3347122780719073
#   (1, 3)	0.2682080718928097
#   (1, 9)	0.5364161437856194
#   (1, 7)	0.2682080718928097
#   (1, 6)	0.37695708675831013
#   (1, 0)	0.37695708675831013
#   (1, 1)	0.37695708675831013
#   (1, 8)	0.37695708675831013
